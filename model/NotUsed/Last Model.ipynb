# %%
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression
import tensorflow as tf

# Plot style.
plt.style.use("ggplot")

# Plot size.
plt.rcParams['figure.figsize'] = [14, 8]

# %%
data = pd.read_csv('powerproduction.csv')  # load data set

# %%
data = pd.DataFrame(data,columns=['speed','power'])
data
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])
])
model.compile(loss='mean_squared_error', 
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(data.power, data.speed, epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 0s 694us/step - loss: 8849.1523
# Epoch 2/500
# 50/50 [==============================] - 0s 714us/step - loss: 243.5539
# Epoch 3/500
# 50/50 [==============================] - 0s 694us/step - loss: 142.0702
# Epoch 4/500
# 50/50 [==============================] - 0s 673us/step - loss: 112.4832
# Epoch 5/500
# 50/50 [==============================] - 0s 673us/step - loss: 88.6871
# Epoch 6/500
# 50/50 [==============================] - 0s 755us/step - loss: 71.1613
# Epoch 7/500
# 50/50 [==============================] - 0s 633us/step - loss: 56.7900
# Epoch 8/500
# 50/50 [==============================] - 0s 673us/step - loss: 46.1719
# Epoch 9/500
# 50/50 [==============================] - 0s 694us/step - loss: 37.9951
# Epoch 10/500
# 50/50 [==============================] - 0s 673us/step - loss: 31.6836
# Epoch 11/500
# 50/50 [==============================] - 0s 694us/step - loss: 27.0392
# Epoch 12/500
# ...

# %%
plt.xlabel("Epoch Number")
plt.ylabel("Loss Magnidute")
plt.plot(data.speed, data.power,'o', label='actual',markerfacecolor='blue', markersize=3)
plt.xlabel("Power")
plt.ylabel("Speed")
plt.plot(data.speed,history, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-cc384479c207> in <module>
#       1 plt.xlabel("Epoch Number")
#       2 plt.ylabel("Loss Magnidute")
# ----> 3 plt.plot(data.speed, history,'o', label='actual',markerfacecolor='blue', markersize=3)
#       4 plt.xlabel("Power")
#       5 plt.ylabel("Speed")
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...
