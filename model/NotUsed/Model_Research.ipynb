# %%
# The first library that we need to import is pandas, 
# which is a portmanteau of “panel data” and is the most 
# popular Python library for working with tabular data.
import pandas as pd

#  library for numerical computing.
import numpy as np

#  library for data visualization.
import matplotlib.pyplot as plt


# %matplotlib inline

# another Python data visualization
import seaborn as sns

# %%
raw_data = pd.read_csv('powerproduction.csv')
sns.pairplot(raw_data)

# %%
x = raw_data[['speed']]

# %%
y = raw_data[['power']]

# %% [markdown]
# ## Splitting the Training Data

# %%
# scikit-learn makes it very easy to divide our data set into training data and test data. To do this, 
# we’ll need to import the function train_test_split from the model_selection module of scikit-learn.
from sklearn.model_selection import train_test_split

# %%
#The train_test_split data accepts three arguments:

# Our x-array
# Our y-array
# The desired size of our test data
# With these parameters, the train_test_split function will split our data for us! 
# Here’s the code to do this if we want our test data to be 30% of the entire data set:
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %%
# The train_test_split function returns a Python list of length 4, where each 
#item in the list is x_train, x_test, y_train, and y_test, respectively.
# We then use list unpacking to assign the proper 
# values to the correct variable names.

# %%
# Building and Training the Model
# The first thing we need to do is import the LinearRegression estimator from scikit-learn. 
# Here is the Python statement for this:


from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [[4.86741762]]

# %%
print(model.intercept_)
# Out:
# [-13.50657532]

# %%
pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])
# Out:
#           Coeff
# speed  4.867418

# %%
# Train the neural network on our training data.
model.fit(train['x'], train['y'], epochs=500)
predictions = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-e66274e0fa0c> in <module>
#       1 # Train the neural network on our training data.
# ----> 2 model.fit(train['x'], train['y'], epochs=500)
#       3 predictions = model.predict(x_test)
#
# NameError: name 'train' is not defined

# %%
newvalue = model.predict(x)
plt.title('Actual vs Predicted')
plt.scatter(x, y,label='actual')
plt.plot(x, newvalue,'r.',label='prediction')
plt.xlabel("Speed")
plt.ylabel("Power")
plt.legend()

# %%
# plt.hist(y_test - predictions)

# %%
# References
# https://www.freecodecamp.org/news/how-to-build-and-train-linear-and-logistic-regression-ml-models-in-python/

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8ad66b01291f> in <module>
#       1 # Now let's see.
# ----> 2 plt.plot(poly['x'], poly['y'], label='actual')
#       3 plt.plot(poly['x'], model.predict(poly['x']), label='prediction')
#       4 plt.legend();
#
# NameError: name 'poly' is not defined
